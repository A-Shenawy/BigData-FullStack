# %%
import csv
import sqlite3
import os
from datetime import datetime

# Path to your CSV
csv_file_path = r"D:/Other/1- Masters Data/2- Big Data Course/project/mimic-iii-clinical-database-demo-1.4/mimic-iii-clinical-database-demo-1.4/ADMISSIONS.csv"

# Extract the CSV file name without extension
table_name = os.path.splitext(os.path.basename(csv_file_path))[0]

# Connect to SQLite database (this will create a file-based database)
conn = sqlite3.connect('mimiciii.db')  # Database will be saved as 'mimiciii.db'
cursor = conn.cursor()

# Function to infer column data type based on sample values
def infer_data_type(sample_values):
    # Try to match DATE (common formats like YYYY-MM-DD, MM/DD/YYYY)
    date_formats = ["%Y-%m-%d", "%m/%d/%Y", "%d/%m/%Y"]
    for val in sample_values:
        if isinstance(val, str):
            for fmt in date_formats:
                try:
                    datetime.strptime(val, fmt)
                    return 'DATE'
                except ValueError:
                    continue
    
    # Try to detect BOOLEAN (True, False, 1, 0, yes, no, etc.)
    boolean_values = {"true", "false", "1", "0", "yes", "no"}
    for val in sample_values:
        if val.lower() in boolean_values:
            return 'BOOLEAN'

    # Check if it's an integer
    for val in sample_values:
        try:
            int(val)
            return 'INTEGER'
        except ValueError:
            pass

    # Check if it's a float
    for val in sample_values:
        try:
            float(val)
            return 'REAL'
        except ValueError:
            pass

    # If it can't be identified as numeric or boolean, default to TEXT
    return 'TEXT'


# Read the CSV file to detect schema
with open(csv_file_path, 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    columns = reader.fieldnames
    # Create a dictionary to store data types for each column
    column_types = {}

    # Sample each column (use the first few rows) to detect types
    sample_rows = [next(reader) for _ in range(10)]  # Get 10 sample rows from the file
    for column in columns:
        # Get the sample values for each column
        sample_values = [row[column] for row in sample_rows if row[column] != '']
        
        # Infer the data type for the column based on the sample values
        if sample_values:
            column_types[column] = infer_data_type(sample_values)
        else:
            column_types[column] = 'TEXT'  # Default to TEXT if no data in the sample

    # Create table with columns and inferred data types
    create_table_query = f"CREATE TABLE {table_name} ({', '.join([col + ' ' + column_types[col] for col in columns])});"
    cursor.execute(create_table_query)

    # Reset the reader to start inserting data
    csvfile.seek(0)
    reader = csv.DictReader(csvfile)
    
    # Insert data into SQLite database
    for row in reader:
        placeholders = ', '.join(['?' for _ in row])
        insert_query = f"INSERT INTO {table_name} ({', '.join(columns)}) VALUES ({placeholders});"
        cursor.execute(insert_query, tuple(row.values()))

# Commit and check if successful
conn.commit()

# Now to inspect the schema of the created table
cursor.execute(f"PRAGMA table_info({table_name});")
schema = cursor.fetchall()

# Print the schema
print(f"Schema of '{table_name}' table:")
for column in schema:
    print(column)

# Close the connection
conn.close()
# Out:
# Schema of 'ADMISSIONS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'admittime', 'TEXT', 0, None, 0)
# (4, 'dischtime', 'TEXT', 0, None, 0)
# (5, 'deathtime', 'TEXT', 0, None, 0)
# (6, 'admission_type', 'TEXT', 0, None, 0)
# (7, 'admission_location', 'TEXT', 0, None, 0)
# (8, 'discharge_location', 'TEXT', 0, None, 0)
# (9, 'insurance', 'TEXT', 0, None, 0)
# (10, 'language', 'TEXT', 0, None, 0)
# (11, 'religion', 'TEXT', 0, None, 0)
# (12, 'marital_status', 'TEXT', 0, None, 0)
# (13, 'ethnicity', 'TEXT', 0, None, 0)
# (14, 'edregtime', 'TEXT', 0, None, 0)
# (15, 'edouttime', 'TEXT', 0, None, 0)
# (16, 'diagnosis', 'TEXT', 0, None, 0)
# (17, 'hospital_expire_flag', 'BOOLEAN', 0, None, 0)
# (18, 'has_chartevents_data', 'BOOLEAN', 0, None, 0)

# %%
import csv
import sqlite3
import os
from datetime import datetime

# Folder path to your CSV files
folder_path = r"D:/Other/1- Masters Data/2- Big Data Course/project/mimic-iii-clinical-database-demo-1.4/mimic-iii-clinical-database-demo-1.4"

# Function to infer column data type based on sample values
def infer_data_type(sample_values):
    # Try to match DATE (common formats like YYYY-MM-DD, MM/DD/YYYY)
    date_formats = ["%Y-%m-%d", "%m/%d/%Y", "%d/%m/%Y"]
    for val in sample_values:
        if isinstance(val, str):
            for fmt in date_formats:
                try:
                    datetime.strptime(val, fmt)
                    return 'DATE'
                except ValueError:
                    continue
    
    # Try to detect BOOLEAN (True, False, 1, 0, yes, no, etc.)
    boolean_values = {"true", "false", "1", "0", "yes", "no"}
    for val in sample_values:
        if val.lower() in boolean_values:
            return 'BOOLEAN'

    # Check if it's an integer
    for val in sample_values:
        try:
            int(val)
            return 'INTEGER'
        except ValueError:
            pass

    # Check if it's a float
    for val in sample_values:
        try:
            float(val)
            return 'REAL'
        except ValueError:
            pass

    # If it can't be identified as numeric or boolean, default to TEXT
    return 'TEXT'


# Loop through all CSV files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        # Get the full file path
        csv_file_path = os.path.join(folder_path, filename)
        
        # Extract the table name (using the file name without the .csv extension)
        table_name = os.path.splitext(filename)[0]

        # Connect to SQLite database (this will create a file-based database)
        conn = sqlite3.connect('mimiciii.db')  # Database will be saved as 'mimiciii.db'
        cursor = conn.cursor()

        # Read the CSV file to detect schema
        with open(csv_file_path, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            columns = reader.fieldnames
            # Create a dictionary to store data types for each column
            column_types = {}

            # Get all rows and sample from them (use the first 10 or fewer if the file has less)
            all_rows = list(reader)
            sample_rows = all_rows[:10] if len(all_rows) >= 10 else all_rows  # Sample at most 10 rows
            for column in columns:
                # Get the sample values for each column
                sample_values = [row[column] for row in sample_rows if row[column] != '']
                
                # Infer the data type for the column based on the sample values
                if sample_values:
                    column_types[column] = infer_data_type(sample_values)
                else:
                    column_types[column] = 'TEXT'  # Default to TEXT if no data in the sample

            # Create table with columns and inferred data types (Only if it doesn't already exist)
            create_table_query = f"CREATE TABLE IF NOT EXISTS {table_name} ({', '.join([col + ' ' + column_types[col] for col in columns])});"
            cursor.execute(create_table_query)

            # Reset the reader to start inserting data
            csvfile.seek(0)
            reader = csv.DictReader(csvfile)
            
            # Insert data into SQLite database
            for row in reader:
                placeholders = ', '.join(['?' for _ in row])
                insert_query = f"INSERT INTO {table_name} ({', '.join(columns)}) VALUES ({placeholders});"
                cursor.execute(insert_query, tuple(row.values()))

        # Commit and check if successful
        conn.commit()

        # Now to inspect the schema of the created table
        cursor.execute(f"PRAGMA table_info({table_name});")
        schema = cursor.fetchall()

        # Print the schema
        print(f"Schema of '{table_name}' table:")
        for column in schema:
            print(column)

        # Close the connection
        conn.close()
# Out:
# Schema of 'ADMISSIONS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'admittime', 'TEXT', 0, None, 0)
# (4, 'dischtime', 'TEXT', 0, None, 0)
# (5, 'deathtime', 'TEXT', 0, None, 0)
# (6, 'admission_type', 'TEXT', 0, None, 0)
# (7, 'admission_location', 'TEXT', 0, None, 0)
# (8, 'discharge_location', 'TEXT', 0, None, 0)
# (9, 'insurance', 'TEXT', 0, None, 0)
# (10, 'language', 'TEXT', 0, None, 0)
# (11, 'religion', 'TEXT', 0, None, 0)
# (12, 'marital_status', 'TEXT', 0, None, 0)
# (13, 'ethnicity', 'TEXT', 0, None, 0)
# (14, 'edregtime', 'TEXT', 0, None, 0)
# (15, 'edouttime', 'TEXT', 0, None, 0)
# (16, 'diagnosis', 'TEXT', 0, None, 0)
# (17, 'hospital_expire_flag', 'BOOLEAN', 0, None, 0)
# (18, 'has_chartevents_data', 'BOOLEAN', 0, None, 0)
# Schema of 'CALLOUT' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'submit_wardid', 'INTEGER', 0, None, 0)
# (4, 'submit_careunit', 'TEXT', 0, None, 0)
# (5, 'curr_wardid', 'INTEGER', 0, None, 0)
# (6, 'curr_careunit', 'TEXT', 0, None, 0)
# (7, 'callout_wardid', 'BOOLEAN', 0, None, 0)
# (8, 'callout_service', 'TEXT', 0, None, 0)
# (9, 'request_tele', 'BOOLEAN', 0, None, 0)
# (10, 'request_resp', 'BOOLEAN', 0, None, 0)
# (11, 'request_cdiff', 'BOOLEAN', 0, None, 0)
# (12, 'request_mrsa', 'BOOLEAN', 0, None, 0)
# (13, 'request_vre', 'BOOLEAN', 0, None, 0)
# (14, 'callout_status', 'TEXT', 0, None, 0)
# (15, 'callout_outcome', 'TEXT', 0, None, 0)
# (16, 'discharge_wardid', 'INTEGER', 0, None, 0)
# (17, 'acknowledge_status', 'TEXT', 0, None, 0)
# (18, 'createtime', 'TEXT', 0, None, 0)
# (19, 'updatetime', 'TEXT', 0, None, 0)
# (20, 'acknowledgetime', 'TEXT', 0, None, 0)
# (21, 'outcometime', 'TEXT', 0, None, 0)
# (22, 'firstreservationtime', 'TEXT', 0, None, 0)
# (23, 'currentreservationtime', 'TEXT', 0, None, 0)
# Schema of 'CAREGIVERS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'cgid', 'INTEGER', 0, None, 0)
# (2, 'label', 'TEXT', 0, None, 0)
# (3, 'description', 'TEXT', 0, None, 0)
# Schema of 'CHARTEVENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'itemid', 'INTEGER', 0, None, 0)
# (5, 'charttime', 'TEXT', 0, None, 0)
# (6, 'storetime', 'TEXT', 0, None, 0)
# (7, 'cgid', 'INTEGER', 0, None, 0)
# (8, 'value', 'INTEGER', 0, None, 0)
# (9, 'valuenum', 'INTEGER', 0, None, 0)
# (10, 'valueuom', 'TEXT', 0, None, 0)
# (11, 'warning', 'BOOLEAN', 0, None, 0)
# (12, 'error', 'BOOLEAN', 0, None, 0)
# (13, 'resultstatus', 'TEXT', 0, None, 0)
# (14, 'stopped', 'TEXT', 0, None, 0)
# Schema of 'CPTEVENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'costcenter', 'TEXT', 0, None, 0)
# (4, 'chartdate', 'TEXT', 0, None, 0)
# (5, 'cpt_cd', 'INTEGER', 0, None, 0)
# (6, 'cpt_number', 'INTEGER', 0, None, 0)
# (7, 'cpt_suffix', 'TEXT', 0, None, 0)
# (8, 'ticket_id_seq', 'BOOLEAN', 0, None, 0)
# (9, 'sectionheader', 'TEXT', 0, None, 0)
# (10, 'subsectionheader', 'TEXT', 0, None, 0)
# (11, 'description', 'TEXT', 0, None, 0)
# Schema of 'DATETIMEEVENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'itemid', 'INTEGER', 0, None, 0)
# (5, 'charttime', 'TEXT', 0, None, 0)
# (6, 'storetime', 'TEXT', 0, None, 0)
# (7, 'cgid', 'INTEGER', 0, None, 0)
# (8, 'value', 'TEXT', 0, None, 0)
# (9, 'valueuom', 'TEXT', 0, None, 0)
# (10, 'warning', 'TEXT', 0, None, 0)
# (11, 'error', 'TEXT', 0, None, 0)
# (12, 'resultstatus', 'TEXT', 0, None, 0)
# (13, 'stopped', 'TEXT', 0, None, 0)
# Schema of 'DIAGNOSES_ICD' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'seq_num', 'BOOLEAN', 0, None, 0)
# (4, 'icd9_code', 'INTEGER', 0, None, 0)
# Schema of 'DRGCODES' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'drg_type', 'TEXT', 0, None, 0)
# (4, 'drg_code', 'INTEGER', 0, None, 0)
# (5, 'description', 'TEXT', 0, None, 0)
# (6, 'drg_severity', 'TEXT', 0, None, 0)
# (7, 'drg_mortality', 'TEXT', 0, None, 0)
# Schema of 'D_CPT' table:
# (0, 'row_id', 'BOOLEAN', 0, None, 0)
# (1, 'category', 'BOOLEAN', 0, None, 0)
# (2, 'sectionrange', 'TEXT', 0, None, 0)
# (3, 'sectionheader', 'TEXT', 0, None, 0)
# (4, 'subsectionrange', 'TEXT', 0, None, 0)
# (5, 'subsectionheader', 'TEXT', 0, None, 0)
# (6, 'codesuffix', 'TEXT', 0, None, 0)
# (7, 'mincodeinsubsection', 'INTEGER', 0, None, 0)
# (8, 'maxcodeinsubsection', 'INTEGER', 0, None, 0)
# Schema of 'D_ICD_DIAGNOSES' table:
# (0, 'row_id', 'BOOLEAN', 0, None, 0)
# (1, 'icd9_code', 'INTEGER', 0, None, 0)
# (2, 'short_title', 'TEXT', 0, None, 0)
# (3, 'long_title', 'TEXT', 0, None, 0)
# Schema of 'D_ICD_PROCEDURES' table:
# (0, 'row_id', 'BOOLEAN', 0, None, 0)
# (1, 'icd9_code', 'INTEGER', 0, None, 0)
# (2, 'short_title', 'TEXT', 0, None, 0)
# (3, 'long_title', 'TEXT', 0, None, 0)
# Schema of 'D_ITEMS' table:
# (0, 'row_id', 'BOOLEAN', 0, None, 0)
# (1, 'itemid', 'INTEGER', 0, None, 0)
# (2, 'label', 'TEXT', 0, None, 0)
# (3, 'abbreviation', 'TEXT', 0, None, 0)
# (4, 'dbsource', 'TEXT', 0, None, 0)
# (5, 'linksto', 'TEXT', 0, None, 0)
# (6, 'category', 'TEXT', 0, None, 0)
# (7, 'unitname', 'TEXT', 0, None, 0)
# (8, 'param_type', 'TEXT', 0, None, 0)
# (9, 'conceptid', 'TEXT', 0, None, 0)
# Schema of 'D_LABITEMS' table:
# (0, 'row_id', 'BOOLEAN', 0, None, 0)
# (1, 'itemid', 'INTEGER', 0, None, 0)
# (2, 'label', 'TEXT', 0, None, 0)
# (3, 'fluid', 'TEXT', 0, None, 0)
# (4, 'category', 'TEXT', 0, None, 0)
# (5, 'loinc_code', 'TEXT', 0, None, 0)
# Schema of 'ICUSTAYS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'dbsource', 'TEXT', 0, None, 0)
# (5, 'first_careunit', 'TEXT', 0, None, 0)
# (6, 'last_careunit', 'TEXT', 0, None, 0)
# (7, 'first_wardid', 'INTEGER', 0, None, 0)
# (8, 'last_wardid', 'INTEGER', 0, None, 0)
# (9, 'intime', 'TEXT', 0, None, 0)
# (10, 'outtime', 'TEXT', 0, None, 0)
# (11, 'los', 'REAL', 0, None, 0)
# Schema of 'INPUTEVENTS_CV' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'charttime', 'TEXT', 0, None, 0)
# (5, 'itemid', 'INTEGER', 0, None, 0)
# (6, 'amount', 'BOOLEAN', 0, None, 0)
# (7, 'amountuom', 'TEXT', 0, None, 0)
# (8, 'rate', 'TEXT', 0, None, 0)
# (9, 'rateuom', 'TEXT', 0, None, 0)
# (10, 'storetime', 'TEXT', 0, None, 0)
# (11, 'cgid', 'INTEGER', 0, None, 0)
# (12, 'orderid', 'INTEGER', 0, None, 0)
# (13, 'linkorderid', 'INTEGER', 0, None, 0)
# (14, 'stopped', 'TEXT', 0, None, 0)
# (15, 'newbottle', 'TEXT', 0, None, 0)
# (16, 'originalamount', 'TEXT', 0, None, 0)
# (17, 'originalamountuom', 'TEXT', 0, None, 0)
# (18, 'originalroute', 'TEXT', 0, None, 0)
# (19, 'originalrate', 'TEXT', 0, None, 0)
# (20, 'originalrateuom', 'TEXT', 0, None, 0)
# (21, 'originalsite', 'TEXT', 0, None, 0)
# Schema of 'INPUTEVENTS_MV' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'starttime', 'TEXT', 0, None, 0)
# (5, 'endtime', 'TEXT', 0, None, 0)
# (6, 'itemid', 'INTEGER', 0, None, 0)
# (7, 'amount', 'INTEGER', 0, None, 0)
# (8, 'amountuom', 'TEXT', 0, None, 0)
# (9, 'rate', 'REAL', 0, None, 0)
# (10, 'rateuom', 'TEXT', 0, None, 0)
# (11, 'storetime', 'TEXT', 0, None, 0)
# (12, 'cgid', 'INTEGER', 0, None, 0)
# (13, 'orderid', 'INTEGER', 0, None, 0)
# (14, 'linkorderid', 'INTEGER', 0, None, 0)
# (15, 'ordercategoryname', 'TEXT', 0, None, 0)
# (16, 'secondaryordercategoryname', 'TEXT', 0, None, 0)
# (17, 'ordercomponenttypedescription', 'TEXT', 0, None, 0)
# (18, 'ordercategorydescription', 'TEXT', 0, None, 0)
# (19, 'patientweight', 'INTEGER', 0, None, 0)
# (20, 'totalamount', 'INTEGER', 0, None, 0)
# (21, 'totalamountuom', 'TEXT', 0, None, 0)
# (22, 'isopenbag', 'BOOLEAN', 0, None, 0)
# (23, 'continueinnextdept', 'BOOLEAN', 0, None, 0)
# (24, 'cancelreason', 'BOOLEAN', 0, None, 0)
# (25, 'statusdescription', 'TEXT', 0, None, 0)
# (26, 'comments_editedby', 'TEXT', 0, None, 0)
# (27, 'comments_canceledby', 'TEXT', 0, None, 0)
# (28, 'comments_date', 'TEXT', 0, None, 0)
# (29, 'originalamount', 'INTEGER', 0, None, 0)
# (30, 'originalrate', 'INTEGER', 0, None, 0)
# Schema of 'LABEVENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'TEXT', 0, None, 0)
# (3, 'itemid', 'INTEGER', 0, None, 0)
# (4, 'charttime', 'TEXT', 0, None, 0)
# (5, 'value', 'INTEGER', 0, None, 0)
# (6, 'valuenum', 'INTEGER', 0, None, 0)
# (7, 'valueuom', 'TEXT', 0, None, 0)
# (8, 'flag', 'TEXT', 0, None, 0)
# Schema of 'MICROBIOLOGYEVENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'chartdate', 'TEXT', 0, None, 0)
# (4, 'charttime', 'TEXT', 0, None, 0)
# (5, 'spec_itemid', 'INTEGER', 0, None, 0)
# (6, 'spec_type_desc', 'TEXT', 0, None, 0)
# (7, 'org_itemid', 'INTEGER', 0, None, 0)
# (8, 'org_name', 'TEXT', 0, None, 0)
# (9, 'isolate_num', 'BOOLEAN', 0, None, 0)
# (10, 'ab_itemid', 'INTEGER', 0, None, 0)
# (11, 'ab_name', 'TEXT', 0, None, 0)
# (12, 'dilution_text', 'INTEGER', 0, None, 0)
# (13, 'dilution_comparison', 'TEXT', 0, None, 0)
# (14, 'dilution_value', 'BOOLEAN', 0, None, 0)
# (15, 'interpretation', 'TEXT', 0, None, 0)
# Schema of 'NOTEEVENTS' table:
# (0, 'row_id', 'TEXT', 0, None, 0)
# (1, 'subject_id', 'TEXT', 0, None, 0)
# (2, 'hadm_id', 'TEXT', 0, None, 0)
# (3, 'chartdate', 'TEXT', 0, None, 0)
# (4, 'charttime', 'TEXT', 0, None, 0)
# (5, 'storetime', 'TEXT', 0, None, 0)
# (6, 'category', 'TEXT', 0, None, 0)
# (7, 'description', 'TEXT', 0, None, 0)
# (8, 'cgid', 'TEXT', 0, None, 0)
# (9, 'iserror', 'TEXT', 0, None, 0)
# (10, 'text', 'TEXT', 0, None, 0)
# Schema of 'OUTPUTEVENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'charttime', 'TEXT', 0, None, 0)
# (5, 'itemid', 'INTEGER', 0, None, 0)
# (6, 'value', 'INTEGER', 0, None, 0)
# (7, 'valueuom', 'TEXT', 0, None, 0)
# (8, 'storetime', 'TEXT', 0, None, 0)
# (9, 'cgid', 'INTEGER', 0, None, 0)
# (10, 'stopped', 'TEXT', 0, None, 0)
# (11, 'newbottle', 'TEXT', 0, None, 0)
# (12, 'iserror', 'TEXT', 0, None, 0)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[10], line 93
#      91         placeholders = ', '.join(['?' for _ in row])
#      92         insert_query = f"INSERT INTO {table_name} ({', '.join(columns)}) VALUES ({placeholders});"
# ---> 93         cursor.execute(insert_query, tuple(row.values()))
#      95 # Commit and check if successful
#      96 conn.commit()
#
# OperationalError: table PATIENTS has no column named gender

# %%
import csv
import sqlite3
import os
from datetime import datetime

# Folder path to your CSV files
folder_path = r"D:/Other/1- Masters Data/2- Big Data Course/project/mimic-iii-clinical-database-demo-1.4/mimic-iii-clinical-database-demo-1.4"

# Function to infer column data type based on sample values
def infer_data_type(sample_values):
    # Try to match DATE (common formats like YYYY-MM-DD, MM/DD/YYYY)
    date_formats = ["%Y-%m-%d", "%m/%d/%Y", "%d/%m/%Y"]
    for val in sample_values:
        if isinstance(val, str):
            for fmt in date_formats:
                try:
                    datetime.strptime(val, fmt)
                    return 'DATE'
                except ValueError:
                    continue
    
    # Try to detect BOOLEAN (True, False, 1, 0, yes, no, etc.)
    boolean_values = {"true", "false", "1", "0", "yes", "no"}
    for val in sample_values:
        if val.lower() in boolean_values:
            return 'BOOLEAN'

    # Check if it's an integer
    for val in sample_values:
        try:
            int(val)
            return 'INTEGER'
        except ValueError:
            pass

    # Check if it's a float
    for val in sample_values:
        try:
            float(val)
            return 'REAL'
        except ValueError:
            pass

    # If it can't be identified as numeric or boolean, default to TEXT
    return 'TEXT'


# Loop through all CSV files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        # Get the full file path
        csv_file_path = os.path.join(folder_path, filename)
        
        # Extract the table name (using the file name without the .csv extension)
        table_name = os.path.splitext(filename)[0]

        # Connect to SQLite database (this will create a file-based database)
        conn = sqlite3.connect('mimiciii.db')  # Database will be saved as 'mimiciii.db'
        cursor = conn.cursor()

        # Read the CSV file to detect schema
        with open(csv_file_path, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            columns = reader.fieldnames
            # Create a dictionary to store data types for each column
            column_types = {}

            # Get all rows and sample from them (use the first 10 or fewer if the file has less)
            all_rows = list(reader)
            sample_rows = all_rows[:10] if len(all_rows) >= 10 else all_rows  # Sample at most 10 rows
            for column in columns:
                # Get the sample values for each column
                sample_values = [row[column] for row in sample_rows if row[column] != '']
                
                # Infer the data type for the column based on the sample values
                if sample_values:
                    column_types[column] = infer_data_type(sample_values)
                else:
                    column_types[column] = 'TEXT'  # Default to TEXT if no data in the sample

            # Create table with columns and inferred data types (Only if it doesn't already exist)
            create_table_query = f"CREATE TABLE IF NOT EXISTS {table_name} ({', '.join([col + ' ' + column_types[col] for col in columns])});"
            cursor.execute(create_table_query)

            # Checking and adding missing columns dynamically
            cursor.execute(f"PRAGMA table_info({table_name});")
            existing_columns = [column[1] for column in cursor.fetchall()]
            missing_columns = [col for col in columns if col not in existing_columns]
            
            if missing_columns:
                for column in missing_columns:
                    # Infer the data type for the missing column from the CSV sample
                    column_data_type = infer_data_type([row[column] for row in sample_rows if row[column] != ''])
                    alter_query = f"ALTER TABLE {table_name} ADD COLUMN {column} {column_data_type};"
                    cursor.execute(alter_query)

            # Now insert data into the table
            csvfile.seek(0)  # Reset to start inserting data
            reader = csv.DictReader(csvfile)
            for row in reader:
                placeholders = ', '.join(['?' for _ in row])
                insert_query = f"INSERT INTO {table_name} ({', '.join(columns)}) VALUES ({placeholders});"
                cursor.execute(insert_query, tuple(row.values()))

        # Commit and check if successful
        conn.commit()

        # Now to inspect the schema of the created table
        cursor.execute(f"PRAGMA table_info({table_name});")
        schema = cursor.fetchall()

        # Print the schema
        print(f"Schema of '{table_name}' table:")
        for column in schema:
            print(column)

        # Close the connection
        conn.close()
# Out:
# Schema of 'ADMISSIONS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'admittime', 'TEXT', 0, None, 0)
# (4, 'dischtime', 'TEXT', 0, None, 0)
# (5, 'deathtime', 'TEXT', 0, None, 0)
# (6, 'admission_type', 'TEXT', 0, None, 0)
# (7, 'admission_location', 'TEXT', 0, None, 0)
# (8, 'discharge_location', 'TEXT', 0, None, 0)
# (9, 'insurance', 'TEXT', 0, None, 0)
# (10, 'language', 'TEXT', 0, None, 0)
# (11, 'religion', 'TEXT', 0, None, 0)
# (12, 'marital_status', 'TEXT', 0, None, 0)
# (13, 'ethnicity', 'TEXT', 0, None, 0)
# (14, 'edregtime', 'TEXT', 0, None, 0)
# (15, 'edouttime', 'TEXT', 0, None, 0)
# (16, 'diagnosis', 'TEXT', 0, None, 0)
# (17, 'hospital_expire_flag', 'BOOLEAN', 0, None, 0)
# (18, 'has_chartevents_data', 'BOOLEAN', 0, None, 0)
# Schema of 'CALLOUT' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'submit_wardid', 'INTEGER', 0, None, 0)
# (4, 'submit_careunit', 'TEXT', 0, None, 0)
# (5, 'curr_wardid', 'INTEGER', 0, None, 0)
# (6, 'curr_careunit', 'TEXT', 0, None, 0)
# (7, 'callout_wardid', 'BOOLEAN', 0, None, 0)
# (8, 'callout_service', 'TEXT', 0, None, 0)
# (9, 'request_tele', 'BOOLEAN', 0, None, 0)
# (10, 'request_resp', 'BOOLEAN', 0, None, 0)
# (11, 'request_cdiff', 'BOOLEAN', 0, None, 0)
# (12, 'request_mrsa', 'BOOLEAN', 0, None, 0)
# (13, 'request_vre', 'BOOLEAN', 0, None, 0)
# (14, 'callout_status', 'TEXT', 0, None, 0)
# (15, 'callout_outcome', 'TEXT', 0, None, 0)
# (16, 'discharge_wardid', 'INTEGER', 0, None, 0)
# (17, 'acknowledge_status', 'TEXT', 0, None, 0)
# (18, 'createtime', 'TEXT', 0, None, 0)
# (19, 'updatetime', 'TEXT', 0, None, 0)
# (20, 'acknowledgetime', 'TEXT', 0, None, 0)
# (21, 'outcometime', 'TEXT', 0, None, 0)
# (22, 'firstreservationtime', 'TEXT', 0, None, 0)
# (23, 'currentreservationtime', 'TEXT', 0, None, 0)
# Schema of 'CAREGIVERS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'cgid', 'INTEGER', 0, None, 0)
# (2, 'label', 'TEXT', 0, None, 0)
# (3, 'description', 'TEXT', 0, None, 0)
# Schema of 'CHARTEVENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'itemid', 'INTEGER', 0, None, 0)
# (5, 'charttime', 'TEXT', 0, None, 0)
# (6, 'storetime', 'TEXT', 0, None, 0)
# (7, 'cgid', 'INTEGER', 0, None, 0)
# (8, 'value', 'INTEGER', 0, None, 0)
# (9, 'valuenum', 'INTEGER', 0, None, 0)
# (10, 'valueuom', 'TEXT', 0, None, 0)
# (11, 'warning', 'BOOLEAN', 0, None, 0)
# (12, 'error', 'BOOLEAN', 0, None, 0)
# (13, 'resultstatus', 'TEXT', 0, None, 0)
# (14, 'stopped', 'TEXT', 0, None, 0)
# Schema of 'CPTEVENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'costcenter', 'TEXT', 0, None, 0)
# (4, 'chartdate', 'TEXT', 0, None, 0)
# (5, 'cpt_cd', 'INTEGER', 0, None, 0)
# (6, 'cpt_number', 'INTEGER', 0, None, 0)
# (7, 'cpt_suffix', 'TEXT', 0, None, 0)
# (8, 'ticket_id_seq', 'BOOLEAN', 0, None, 0)
# (9, 'sectionheader', 'TEXT', 0, None, 0)
# (10, 'subsectionheader', 'TEXT', 0, None, 0)
# (11, 'description', 'TEXT', 0, None, 0)
# Schema of 'DATETIMEEVENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'itemid', 'INTEGER', 0, None, 0)
# (5, 'charttime', 'TEXT', 0, None, 0)
# (6, 'storetime', 'TEXT', 0, None, 0)
# (7, 'cgid', 'INTEGER', 0, None, 0)
# (8, 'value', 'TEXT', 0, None, 0)
# (9, 'valueuom', 'TEXT', 0, None, 0)
# (10, 'warning', 'TEXT', 0, None, 0)
# (11, 'error', 'TEXT', 0, None, 0)
# (12, 'resultstatus', 'TEXT', 0, None, 0)
# (13, 'stopped', 'TEXT', 0, None, 0)
# Schema of 'DIAGNOSES_ICD' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'seq_num', 'BOOLEAN', 0, None, 0)
# (4, 'icd9_code', 'INTEGER', 0, None, 0)
# Schema of 'DRGCODES' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'drg_type', 'TEXT', 0, None, 0)
# (4, 'drg_code', 'INTEGER', 0, None, 0)
# (5, 'description', 'TEXT', 0, None, 0)
# (6, 'drg_severity', 'TEXT', 0, None, 0)
# (7, 'drg_mortality', 'TEXT', 0, None, 0)
# Schema of 'D_CPT' table:
# (0, 'row_id', 'BOOLEAN', 0, None, 0)
# (1, 'category', 'BOOLEAN', 0, None, 0)
# (2, 'sectionrange', 'TEXT', 0, None, 0)
# (3, 'sectionheader', 'TEXT', 0, None, 0)
# (4, 'subsectionrange', 'TEXT', 0, None, 0)
# (5, 'subsectionheader', 'TEXT', 0, None, 0)
# (6, 'codesuffix', 'TEXT', 0, None, 0)
# (7, 'mincodeinsubsection', 'INTEGER', 0, None, 0)
# (8, 'maxcodeinsubsection', 'INTEGER', 0, None, 0)
# Schema of 'D_ICD_DIAGNOSES' table:
# (0, 'row_id', 'BOOLEAN', 0, None, 0)
# (1, 'icd9_code', 'INTEGER', 0, None, 0)
# (2, 'short_title', 'TEXT', 0, None, 0)
# (3, 'long_title', 'TEXT', 0, None, 0)
# Schema of 'D_ICD_PROCEDURES' table:
# (0, 'row_id', 'BOOLEAN', 0, None, 0)
# (1, 'icd9_code', 'INTEGER', 0, None, 0)
# (2, 'short_title', 'TEXT', 0, None, 0)
# (3, 'long_title', 'TEXT', 0, None, 0)
# Schema of 'D_ITEMS' table:
# (0, 'row_id', 'BOOLEAN', 0, None, 0)
# (1, 'itemid', 'INTEGER', 0, None, 0)
# (2, 'label', 'TEXT', 0, None, 0)
# (3, 'abbreviation', 'TEXT', 0, None, 0)
# (4, 'dbsource', 'TEXT', 0, None, 0)
# (5, 'linksto', 'TEXT', 0, None, 0)
# (6, 'category', 'TEXT', 0, None, 0)
# (7, 'unitname', 'TEXT', 0, None, 0)
# (8, 'param_type', 'TEXT', 0, None, 0)
# (9, 'conceptid', 'TEXT', 0, None, 0)
# Schema of 'D_LABITEMS' table:
# (0, 'row_id', 'BOOLEAN', 0, None, 0)
# (1, 'itemid', 'INTEGER', 0, None, 0)
# (2, 'label', 'TEXT', 0, None, 0)
# (3, 'fluid', 'TEXT', 0, None, 0)
# (4, 'category', 'TEXT', 0, None, 0)
# (5, 'loinc_code', 'TEXT', 0, None, 0)
# Schema of 'ICUSTAYS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'dbsource', 'TEXT', 0, None, 0)
# (5, 'first_careunit', 'TEXT', 0, None, 0)
# (6, 'last_careunit', 'TEXT', 0, None, 0)
# (7, 'first_wardid', 'INTEGER', 0, None, 0)
# (8, 'last_wardid', 'INTEGER', 0, None, 0)
# (9, 'intime', 'TEXT', 0, None, 0)
# (10, 'outtime', 'TEXT', 0, None, 0)
# (11, 'los', 'REAL', 0, None, 0)
# Schema of 'INPUTEVENTS_CV' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'charttime', 'TEXT', 0, None, 0)
# (5, 'itemid', 'INTEGER', 0, None, 0)
# (6, 'amount', 'BOOLEAN', 0, None, 0)
# (7, 'amountuom', 'TEXT', 0, None, 0)
# (8, 'rate', 'TEXT', 0, None, 0)
# (9, 'rateuom', 'TEXT', 0, None, 0)
# (10, 'storetime', 'TEXT', 0, None, 0)
# (11, 'cgid', 'INTEGER', 0, None, 0)
# (12, 'orderid', 'INTEGER', 0, None, 0)
# (13, 'linkorderid', 'INTEGER', 0, None, 0)
# (14, 'stopped', 'TEXT', 0, None, 0)
# (15, 'newbottle', 'TEXT', 0, None, 0)
# (16, 'originalamount', 'TEXT', 0, None, 0)
# (17, 'originalamountuom', 'TEXT', 0, None, 0)
# (18, 'originalroute', 'TEXT', 0, None, 0)
# (19, 'originalrate', 'TEXT', 0, None, 0)
# (20, 'originalrateuom', 'TEXT', 0, None, 0)
# (21, 'originalsite', 'TEXT', 0, None, 0)
# Schema of 'INPUTEVENTS_MV' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'starttime', 'TEXT', 0, None, 0)
# (5, 'endtime', 'TEXT', 0, None, 0)
# (6, 'itemid', 'INTEGER', 0, None, 0)
# (7, 'amount', 'INTEGER', 0, None, 0)
# (8, 'amountuom', 'TEXT', 0, None, 0)
# (9, 'rate', 'REAL', 0, None, 0)
# (10, 'rateuom', 'TEXT', 0, None, 0)
# (11, 'storetime', 'TEXT', 0, None, 0)
# (12, 'cgid', 'INTEGER', 0, None, 0)
# (13, 'orderid', 'INTEGER', 0, None, 0)
# (14, 'linkorderid', 'INTEGER', 0, None, 0)
# (15, 'ordercategoryname', 'TEXT', 0, None, 0)
# (16, 'secondaryordercategoryname', 'TEXT', 0, None, 0)
# (17, 'ordercomponenttypedescription', 'TEXT', 0, None, 0)
# (18, 'ordercategorydescription', 'TEXT', 0, None, 0)
# (19, 'patientweight', 'INTEGER', 0, None, 0)
# (20, 'totalamount', 'INTEGER', 0, None, 0)
# (21, 'totalamountuom', 'TEXT', 0, None, 0)
# (22, 'isopenbag', 'BOOLEAN', 0, None, 0)
# (23, 'continueinnextdept', 'BOOLEAN', 0, None, 0)
# (24, 'cancelreason', 'BOOLEAN', 0, None, 0)
# (25, 'statusdescription', 'TEXT', 0, None, 0)
# (26, 'comments_editedby', 'TEXT', 0, None, 0)
# (27, 'comments_canceledby', 'TEXT', 0, None, 0)
# (28, 'comments_date', 'TEXT', 0, None, 0)
# (29, 'originalamount', 'INTEGER', 0, None, 0)
# (30, 'originalrate', 'INTEGER', 0, None, 0)
# Schema of 'LABEVENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'TEXT', 0, None, 0)
# (3, 'itemid', 'INTEGER', 0, None, 0)
# (4, 'charttime', 'TEXT', 0, None, 0)
# (5, 'value', 'INTEGER', 0, None, 0)
# (6, 'valuenum', 'INTEGER', 0, None, 0)
# (7, 'valueuom', 'TEXT', 0, None, 0)
# (8, 'flag', 'TEXT', 0, None, 0)
# Schema of 'MICROBIOLOGYEVENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'chartdate', 'TEXT', 0, None, 0)
# (4, 'charttime', 'TEXT', 0, None, 0)
# (5, 'spec_itemid', 'INTEGER', 0, None, 0)
# (6, 'spec_type_desc', 'TEXT', 0, None, 0)
# (7, 'org_itemid', 'INTEGER', 0, None, 0)
# (8, 'org_name', 'TEXT', 0, None, 0)
# (9, 'isolate_num', 'BOOLEAN', 0, None, 0)
# (10, 'ab_itemid', 'INTEGER', 0, None, 0)
# (11, 'ab_name', 'TEXT', 0, None, 0)
# (12, 'dilution_text', 'INTEGER', 0, None, 0)
# (13, 'dilution_comparison', 'TEXT', 0, None, 0)
# (14, 'dilution_value', 'BOOLEAN', 0, None, 0)
# (15, 'interpretation', 'TEXT', 0, None, 0)
# Schema of 'NOTEEVENTS' table:
# (0, 'row_id', 'TEXT', 0, None, 0)
# (1, 'subject_id', 'TEXT', 0, None, 0)
# (2, 'hadm_id', 'TEXT', 0, None, 0)
# (3, 'chartdate', 'TEXT', 0, None, 0)
# (4, 'charttime', 'TEXT', 0, None, 0)
# (5, 'storetime', 'TEXT', 0, None, 0)
# (6, 'category', 'TEXT', 0, None, 0)
# (7, 'description', 'TEXT', 0, None, 0)
# (8, 'cgid', 'TEXT', 0, None, 0)
# (9, 'iserror', 'TEXT', 0, None, 0)
# (10, 'text', 'TEXT', 0, None, 0)
# Schema of 'OUTPUTEVENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'charttime', 'TEXT', 0, None, 0)
# (5, 'itemid', 'INTEGER', 0, None, 0)
# (6, 'value', 'INTEGER', 0, None, 0)
# (7, 'valueuom', 'TEXT', 0, None, 0)
# (8, 'storetime', 'TEXT', 0, None, 0)
# (9, 'cgid', 'INTEGER', 0, None, 0)
# (10, 'stopped', 'TEXT', 0, None, 0)
# (11, 'newbottle', 'TEXT', 0, None, 0)
# (12, 'iserror', 'TEXT', 0, None, 0)
# Schema of 'PATIENTS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'admittime', 'TEXT', 0, None, 0)
# (4, 'dischtime', 'TEXT', 0, None, 0)
# (5, 'deathtime', 'TEXT', 0, None, 0)
# (6, 'admission_type', 'TEXT', 0, None, 0)
# (7, 'admission_location', 'TEXT', 0, None, 0)
# (8, 'discharge_location', 'TEXT', 0, None, 0)
# (9, 'insurance', 'TEXT', 0, None, 0)
# (10, 'language', 'TEXT', 0, None, 0)
# (11, 'religion', 'TEXT', 0, None, 0)
# (12, 'marital_status', 'TEXT', 0, None, 0)
# (13, 'ethnicity', 'TEXT', 0, None, 0)
# (14, 'edregtime', 'TEXT', 0, None, 0)
# (15, 'edouttime', 'TEXT', 0, None, 0)
# (16, 'diagnosis', 'TEXT', 0, None, 0)
# (17, 'hospital_expire_flag', 'BOOLEAN', 0, None, 0)
# (18, 'has_chartevents_data', 'BOOLEAN', 0, None, 0)
# (19, 'gender', 'TEXT', 0, None, 0)
# (20, 'dob', 'TEXT', 0, None, 0)
# (21, 'dod', 'TEXT', 0, None, 0)
# (22, 'dod_hosp', 'TEXT', 0, None, 0)
# (23, 'dod_ssn', 'TEXT', 0, None, 0)
# (24, 'expire_flag', 'BOOLEAN', 0, None, 0)
# Schema of 'PRESCRIPTIONS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'TEXT', 0, None, 0)
# (4, 'startdate', 'TEXT', 0, None, 0)
# (5, 'enddate', 'TEXT', 0, None, 0)
# (6, 'drug_type', 'TEXT', 0, None, 0)
# (7, 'drug', 'TEXT', 0, None, 0)
# (8, 'drug_name_poe', 'TEXT', 0, None, 0)
# (9, 'drug_name_generic', 'TEXT', 0, None, 0)
# (10, 'formulary_drug_cd', 'TEXT', 0, None, 0)
# (11, 'gsn', 'INTEGER', 0, None, 0)
# (12, 'ndc', 'INTEGER', 0, None, 0)
# (13, 'prod_strength', 'TEXT', 0, None, 0)
# (14, 'dose_val_rx', 'BOOLEAN', 0, None, 0)
# (15, 'dose_unit_rx', 'TEXT', 0, None, 0)
# (16, 'form_val_disp', 'BOOLEAN', 0, None, 0)
# (17, 'form_unit_disp', 'TEXT', 0, None, 0)
# (18, 'route', 'TEXT', 0, None, 0)
# Schema of 'PROCEDUREEVENTS_MV' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'starttime', 'TEXT', 0, None, 0)
# (5, 'endtime', 'TEXT', 0, None, 0)
# (6, 'itemid', 'INTEGER', 0, None, 0)
# (7, 'value', 'BOOLEAN', 0, None, 0)
# (8, 'valueuom', 'TEXT', 0, None, 0)
# (9, 'location', 'TEXT', 0, None, 0)
# (10, 'locationcategory', 'TEXT', 0, None, 0)
# (11, 'storetime', 'TEXT', 0, None, 0)
# (12, 'cgid', 'INTEGER', 0, None, 0)
# (13, 'orderid', 'INTEGER', 0, None, 0)
# (14, 'linkorderid', 'INTEGER', 0, None, 0)
# (15, 'ordercategoryname', 'TEXT', 0, None, 0)
# (16, 'secondaryordercategoryname', 'TEXT', 0, None, 0)
# (17, 'ordercategorydescription', 'TEXT', 0, None, 0)
# (18, 'isopenbag', 'BOOLEAN', 0, None, 0)
# (19, 'continueinnextdept', 'BOOLEAN', 0, None, 0)
# (20, 'cancelreason', 'BOOLEAN', 0, None, 0)
# (21, 'statusdescription', 'TEXT', 0, None, 0)
# (22, 'comments_editedby', 'TEXT', 0, None, 0)
# (23, 'comments_canceledby', 'TEXT', 0, None, 0)
# (24, 'comments_date', 'TEXT', 0, None, 0)
# Schema of 'PROCEDURES_ICD' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'seq_num', 'BOOLEAN', 0, None, 0)
# (4, 'icd9_code', 'INTEGER', 0, None, 0)
# Schema of 'SERVICES' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'transfertime', 'TEXT', 0, None, 0)
# (4, 'prev_service', 'TEXT', 0, None, 0)
# (5, 'curr_service', 'TEXT', 0, None, 0)
# Schema of 'TRANSFERS' table:
# (0, 'row_id', 'INTEGER', 0, None, 0)
# (1, 'subject_id', 'INTEGER', 0, None, 0)
# (2, 'hadm_id', 'INTEGER', 0, None, 0)
# (3, 'icustay_id', 'INTEGER', 0, None, 0)
# (4, 'dbsource', 'TEXT', 0, None, 0)
# (5, 'eventtype', 'TEXT', 0, None, 0)
# (6, 'prev_careunit', 'TEXT', 0, None, 0)
# (7, 'curr_careunit', 'TEXT', 0, None, 0)
# (8, 'prev_wardid', 'INTEGER', 0, None, 0)
# (9, 'curr_wardid', 'INTEGER', 0, None, 0)
# (10, 'intime', 'TEXT', 0, None, 0)
# (11, 'outtime', 'TEXT', 0, None, 0)
# (12, 'los', 'REAL', 0, None, 0)

# %%
# %pip install pyhive
# Out:
# Collecting pyhive
#   Downloading PyHive-0.7.0.tar.gz (46 kB)
#      ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
#      -------------------------- ------------- 30.7/46.5 kB 1.4 MB/s eta 0:00:01
#      --------------------------------- ---- 41.0/46.5 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 46.5/46.5 kB 385.5 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting future (from pyhive)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: python-dateutil in c:\users\ahmed.nabawi\.conda\envs\shen\lib\site-packages (from pyhive) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ahmed.nabawi\.conda\envs\shen\lib\site-packages (from python-dateutil->pyhive) (1.16.0)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#     --------------------------------------- 10.2/491.3 kB ? eta -:--:--
#    ----- ---------------------------------- 61.4/491.3 kB 1.1 MB/s eta 0:00:01
#    --------- ---------------------------- 122.9/491.3 kB 901.1 kB/s eta 0:00:01
#    ---------------- ----------------------- 204.8/491.3 kB 1.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 276.5/491.3 kB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 368.6/491.3 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 491.3/491.3 kB 1.5 MB/s eta 0:00:00
# Building wheels for collected packages: pyhive
#   Building wheel for pyhive (setup.py): started
#   Building wheel for pyhive (setup.py): finished with status 'done'
#   Created wheel for pyhive: filename=PyHive-0.7.0-py3-none-any.whl size=53911 sha256=c209054db2c7364fb4320feafe2a1fde261887ff1694d34bbe6a37c4c96f0b67
#   Stored in directory: c:\users\ahmed.nabawi\appdata\local\pip\cache\wheels\9c\da\c6\53fcb35bac0e61bd576a1966283662c6613aece6fe66a2d1f6
# Successfully built pyhive
# Installing collected packages: future, pyhive
# Successfully installed future-1.0.0 pyhive-0.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install thrift
# Out:
# Collecting thrift
#   Downloading thrift-0.21.0.tar.gz (62 kB)
#      ---------------------------------------- 0.0/62.5 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.5 kB ? eta -:--:--
#      ------------------ ------------------- 30.7/62.5 kB 325.1 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/62.5 kB 372.4 kB/s eta 0:00:01
#      -------------------------------------- 62.5/62.5 kB 418.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six>=1.7.2 in c:\users\ahmed.nabawi\.conda\envs\shen\lib\site-packages (from thrift) (1.16.0)
# Building wheels for collected packages: thrift
#   Building wheel for thrift (setup.py): started
#   Building wheel for thrift (setup.py): finished with status 'done'
#   Created wheel for thrift: filename=thrift-0.21.0-py3-none-any.whl size=157418 sha256=f9364e027f689592e72f9415dad2cd89662ef0dd17ec69cfe01948143f6a7eb8
#   Stored in directory: c:\users\ahmed.nabawi\appdata\local\pip\cache\wheels\a4\d6\df\5863f830eabcbc85e1937583ab0aea7d653625d5006b27a780
# Successfully built thrift
# Installing collected packages: thrift
# Successfully installed thrift-0.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install thrift_sasl
# Out:
# Collecting thrift_sasl
#   Downloading thrift_sasl-0.4.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting pure-sasl>=0.6.2 (from thrift_sasl)
#   Downloading pure-sasl-0.6.2.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six>=1.13.0 in c:\users\ahmed.nabawi\.conda\envs\shen\lib\site-packages (from thrift_sasl) (1.16.0)
# Requirement already satisfied: thrift>=0.10.0 in c:\users\ahmed.nabawi\.conda\envs\shen\lib\site-packages (from thrift_sasl) (0.21.0)
# Downloading thrift_sasl-0.4.3-py2.py3-none-any.whl (8.3 kB)
# Building wheels for collected packages: pure-sasl
#   Building wheel for pure-sasl (setup.py): started
#   Building wheel for pure-sasl (setup.py): finished with status 'done'
#   Created wheel for pure-sasl: filename=pure_sasl-0.6.2-py3-none-any.whl size=11439 sha256=7de219a52e12d8976d2f80be6373dceb6a7c391d4de74d8724e1283d1238e754
#   Stored in directory: c:\users\ahmed.nabawi\appdata\local\pip\cache\wheels\af\5e\ca\57ff2c5801d038e3d8b227a4fb492cd84e43a535d64a06f3f2
# Successfully built pure-sasl
# Installing collected packages: pure-sasl, thrift_sasl
# Successfully installed pure-sasl-0.6.2 thrift_sasl-0.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyhive import hive
import csv
import os
from datetime import datetime
import thrift_sasl



# Folder path to your CSV files
folder_path = r"D:/Other/1- Masters Data/2- Big Data Course/project/mimic-iii-clinical-database-demo-1.4/mimic-iii-clinical-database-demo-1.4"

# Function to infer column data type based on sample values
def infer_data_type(sample_values):
    date_formats = ["%Y-%m-%d", "%m/%d/%Y", "%d/%m/%Y"]
    for val in sample_values:
        if isinstance(val, str):
            for fmt in date_formats:
                try:
                    datetime.strptime(val, fmt)
                    return 'DATE'
                except ValueError:
                    continue
    
    boolean_values = {"true", "false", "1", "0", "yes", "no"}
    for val in sample_values:
        if val.lower() in boolean_values:
            return 'BOOLEAN'

    for val in sample_values:
        try:
            int(val)
            return 'INT'
        except ValueError:
            pass

    for val in sample_values:
        try:
            float(val)
            return 'FLOAT'
        except ValueError:
            pass

    return 'STRING'


# Hive connection setup

conn = hive.connect(host='your_hive_host', port=10000, username='hi')
# Hive connection setup#

# Loop through all CSV files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        csv_file_path = os.path.join(folder_path, filename)
        table_name = os.path.splitext(filename)[0]

        # Open CSV file to read columns and sample data
        with open(csv_file_path, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            columns = reader.fieldnames
            sample_rows = [row for row in list(reader)[:10]]  # Sample at most 10 rows
            column_types = {}

            # Infer column data types
            for column in columns:
                sample_values = [row[column] for row in sample_rows if row[column] != '']
                if sample_values:
                    column_types[column] = infer_data_type(sample_values)
                else:
                    column_types[column] = 'STRING'  # Default to STRING if no data in the sample

            # Construct CREATE TABLE query
            create_table_query = f"CREATE TABLE IF NOT EXISTS {table_name} ("
            create_table_query += ", ".join([f"{col} {column_types[col]}" for col in columns]) + ")"
            cursor.execute(create_table_query)

            # Load data into Hive
            load_data_query = f"LOAD DATA LOCAL INPATH '{csv_file_path}' INTO TABLE {table_name}"
            cursor.execute(load_data_query)

        print(f"Table '{table_name}' created and data loaded successfully.")
    
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 44
#      40     return 'STRING'
#      43 # Hive connection setup
# ---> 44 conn = hive.connect(host='your_hive_host', port=10000, username='your_username')
#      45 cursor = conn.cursor()
#      47 # Loop through all CSV files in the folder
#
# File c:\Users\Ahmed.Nabawi\.conda\envs\Shen\lib\site-packages\pyhive\hive.py:143, in connect(*args, **kwargs)
#     137 def connect(*args, **kwargs):
#     138     """Constructor for creating a connection to the database. See class :py:class:`Connection` for
#     139     arguments.
#     140
#     141     :returns: a :py:class:`Connection` object.
#     142     """
# --> 143     return Connection(*args, **kwargs)
#
# File c:\Users\Ahmed.Nabawi\.conda\envs\Shen\lib\site-packages\pyhive\hive.py:242, in Connection.__init__(self, host, port, scheme, username, database, auth, configuration, kerberos_service_name, password, check_hostname, ssl_cert, thrift_transport)
#     239     self._transport = thrift.transport.TTransport.TBufferedTransport(socket)
#     240 elif auth in ('LDAP', 'KERBEROS', 'NONE', 'CUSTOM'):
#     241     # Defer import so package dependency is optional
# --> 242     import thrift_sasl
#     244     if auth == 'KERBEROS':
#     245         # KERBEROS mode in hive.server2.authentication is GSSAPI in sasl library
#     246         sasl_auth = 'GSSAPI'
#
# ModuleNotFoundError: No module named 'thrift_sasl'
